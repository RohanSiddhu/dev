# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("data.csv")
data1 = pd.read_csv("data1.csv")
data2 = pd.read_csv("data2.csv")

data_input = data['input_size'].to_numpy()
data_divide_and_conquer = data['divide_and_conquer'].to_numpy()
data_brute_force = data['brute_force'].to_numpy()

data1_input = data1['input_size'].to_numpy()
data1_divide_and_conquer = data1['divide_and_conquer'].to_numpy()
data1_brute_force = data1['brute_force'].to_numpy()

data2_input = data2['input_size'].to_numpy()
data2_divide_and_conquer = data2['divide_and_conquer'].to_numpy()
data2_brute_force = data2['brute_force'].to_numpy()

x = np.linspace(1, 1000, 1000)

# %% [markdown]
# <h3>1. Square function: y<sub>2</sub> = f(x) = x<sup>2</sup></h3>

# %%
y2 = x ** 2
plt.plot(x,y2)
plt.show()

# %%
plt.plot(data_input, data_brute_force)
plt.show()

# %%
y = x * np.log2(x)
plt.plot(x, y)
plt.show()

# %%
plt.plot(data_input, data_divide_and_conquer)
plt.show()

# %%
plt.plot(x, y)
plt.plot(x, y2)
plt.show()

# %%
plt.plot(data_input, data_divide_and_conquer)
plt.plot(data_input, data_brute_force)
plt.show()

# %%
plt.plot(data1_input, data1_brute_force)
plt.show()

# %%
plt.plot(data1_input, data1_divide_and_conquer)
plt.show()

# %%
plt.plot(data1_input, data1_brute_force)
plt.plot(data1_input, data1_divide_and_conquer)
plt.show()

# %%
plt.plot(data2_input, data2_brute_force)
plt.show()

# %%
plt.plot(data2_input, data2_divide_and_conquer)
plt.show()

# %%
plt.plot(data2_input, data2_brute_force)
plt.plot(data2_input, data2_divide_and_conquer)
plt.show()
